# %% [markdown]
# # **Профильное задание для стажировки VK на направление "Инженер машинного обучения"**
#
# *   Реализованы две модели для сравнения: первая на основе LGBMRanker, вторая на основе CatBoostRanker
# *   Посчитаны метрики NDCG_5, NDCG_10 и NDCG_50

# %%
# !pip install lightgbm

# %%
# !pip install catboost

# %%
# !pip install optuna

# %%
import lightgbm as lgb
from catboost import CatBoostRanker
from catboost import Pool
import pandas as pd
import numpy as np
from sklearn.metrics import ndcg_score
from sklearn.model_selection import RandomizedSearchCV
from copy import deepcopy

# %%
from google.colab import drive

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/intern_task.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ## **Модель LightGBM**

# %%
df = df[df.groupby('query_id').query_id.transform(len) > 1]

# %% [markdown]
# В датасете нет пропусков в каких-либо ячейках, присутствуют только три строки с уникальными query_id

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train_len = int(df.shape[0] * 0.6)
val_len = int(df.shape[0] * 0.8)

# %%
train_df = df[:train_len].copy()
val_df = df[train_len:val_len].copy()
test_df = df[val_len:].copy()

# %%
def get_data(data):
    qids = data.groupby("query_id")["query_id"].count().to_numpy()
    X = data.drop(["query_id", "rank"], axis=1)
    y = data["rank"]
    return qids, X, y

# %%
qids_train, X_train, y_train = get_data(train_df)
qids_val, X_val, y_val = get_data(val_df)
qids_test, X_test, y_test= get_data(test_df)

# %%
X_test.head()
# Out:
#         feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 188206        2.0        0.0        0.0        0.0        2.0        1.0
# 188207        2.0        0.0        2.0        1.0        2.0        1.0
# 188208        2.0        0.0        2.0        2.0        2.0        1.0
# 188209        2.0        2.0        2.0        1.0        2.0        1.0
# 188210        2.0        0.0        2.0        2.0        2.0        1.0
#
#         feature_6  feature_7   feature_8  feature_9  ...  feature_134  \
# 188206        0.0        0.0  800.001700        1.0  ...          0.0
# 188207        0.0        1.0  800.005951        1.0  ...          0.0
# 188208        0.0        1.0  800.010202        1.0  ...          0.0
# 188209        1.0        1.0  800.014452        1.0  ...         61.0
# 188210        0.0        1.0  800.018703        1.0  ...          0.0
#
#         feature_135  feature_136  feature_137  feature_138  feature_139  \
# 188206         0.00     0.000000     0.994411     0.000000          0.0
# 188207         0.00     0.125000     0.994877    11.108381          0.5
# 188208         0.00     0.250000     0.902742    11.108381          1.0
# 188209        36.35     0.100000     0.925872    11.108381          0.5
# 188210         0.00     0.285714     0.971648    11.108381          1.0
#
#         feature_140  feature_141  feature_142  feature_143
# 188206     0.030891     0.000013         43.0         21.5
# 188207     0.025641     0.000008         81.0         40.5
# 188208     0.025862     0.000177         20.0         10.0
# 188209     0.025306     0.000141         88.0         44.0
# 188210     0.069048     0.000306         25.0         12.5
#
# [5 rows x 144 columns]

# %%
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
lgb_model = lgb.LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    verbose = -1,
    learning_rate = 0.08,
    n_estimators = 100,
    num_leaves = 29,
    max_depth =-1
) #{'learning_rate': 0.08, 'n_estimators': 100, 'num_leaves': 25, 'max_depth': 99}

# %%
import optuna
def objective(trial):

    ranking_param_grid = {
        'learning_rate': trial.suggest_float('learning_rate', 0.06, 0.14, step=0.02),
        'n_estimators': trial.suggest_int('n_estimators', 100, 500, step=100),
        'num_leaves': trial.suggest_int('num_leaves', 25, 35, 1),
        'max_depth': trial.suggest_int('max_depth', -1, 500, 50)
    }

    gbm = lgb.LGBMRanker(objective="lambdarank", metric="ndcg",n_jobs=24, **ranking_param_grid)
    gbm.fit(X_train, y_train, group=qids_train, eval_set=[(X_val, y_val)],
                    eval_metric='ndcg', eval_group=[qids_val], eval_at=[10, 50, 100])

    return list(gbm.best_score_['valid_0'].values())[2]

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200)

print(len(study.trials))
print(study.best_trial.params)

# %% [markdown]
# learning_rate = 0.08,
# n_estimators = 100,
# num_leaves = 29,
# max_depth =-1 - лучшие параметры найденные Optuna

# %%
lgb_model.fit(
    X=X_train,
    y=y_train,
    group=qids_train,
    eval_set=[(X_val, y_val)],
    eval_group=[qids_val],
    eval_at=10,
)
# Out:
# LGBMRanker(learning_rate=0.08, metric='ndcg', num_leaves=29,
#            objective='lambdarank', verbose=-1)

# %%
def ndcg_calc(df, X, test_model, kk):
    df['temp_col'] = test_model.predict(X)
    scores = []
    for query_id, group in df.groupby('query_id'):
        rank_true= group['rank'].values.reshape(1, -1)
        rank_pred = group['temp_col'].values.reshape(1, -1)
        try:
            ndcg = ndcg_score(rank_true, rank_pred, k = kk)
            scores.append(ndcg)
        except ValueError:
            continue
    df.drop(columns = ['temp_col'], inplace = True)
    return np.mean(scores)

print(f"Average NDCG@5: {ndcg_calc(test_df, X_test, lgb_model, 5)}")
print(f"Average NDCG@10: {ndcg_calc(test_df, X_test, lgb_model, 10)}")
print(f"Average NDCG@50: {ndcg_calc(test_df, X_test, lgb_model, 50)}")
# Out:
# Average NDCG@5: 0.5337795509649562
# Average NDCG@10: 0.5444772958680018
# Average NDCG@50: 0.6329924174538855

# %% [markdown]
# ## **Модель CatBoost**

# %%
def get_pool(data):
    qids = data["query_id"]
    X = scaler.transform(data.drop(["query_id", "rank"], axis=1))
    y = data["rank"]
    return Pool(X, label = y, group_id = qids)

# %%
P_train = get_pool(train_df)
P_val = get_pool(val_df)
P_test = get_pool(test_df)

# %%
default_parameters = {}

# %%
def fit_model(loss_function, additional_params=None, train_pool=P_train, test_pool=P_test):
    parameters = deepcopy(default_parameters)
    parameters['loss_function'] = loss_function
    parameters['train_dir'] = loss_function

    if additional_params is not None:
        parameters.update(additional_params)

    model = CatBoostRanker(**parameters)
    model.fit(train_pool, eval_set=test_pool, plot=True)

    return model

# %%
catboost_model = fit_model('YetiRank', {
    'custom_metric': ['NDCG:top=5', 'MAP:top=10', 'NDCG:top=10'],
    'iterations' : 10000,
    'task_type' : 'GPU',
    'metric_period' : 100
    })
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Metric NDCG:type=Base is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# Metric NDCG:type=Base is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# Metric NDCG:top=5;type=Base is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# Metric MAP:top=10 is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# Metric NDCG:top=10;type=Base is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# 0:	test: 0.7143065	best: 0.7143065 (0)	total: 34.2ms	remaining: 5m 42s
# 100:	test: 0.7768248	best: 0.7768248 (100)	total: 1.05s	remaining: 1m 43s
# 200:	test: 0.7838938	best: 0.7838938 (200)	total: 1.93s	remaining: 1m 34s
# 300:	test: 0.7872023	best: 0.7872023 (300)	total: 2.8s	remaining: 1m 30s
# 400:	test: 0.7893885	best: 0.7893885 (400)	total: 3.63s	remaining: 1m 26s
# 500:	test: 0.7920726	best: 0.7920726 (500)	total: 4.5s	remaining: 1m 25s
# 600:	test: 0.7932348	best: 0.7932348 (600)	total: 5.35s	remaining: 1m 23s
# 700:	test: 0.7936101	best: 0.7936101 (700)	total: 6.66s	remaining: 1m 28s
# 800:	test: 0.7952112	best: 0.7952112 (800)	total: 9.44s	remaining: 1m 48s
# 900:	test: 0.7957301	best: 0.7957301 (900)	total: 10.3s	remaining: 1m 44s
# 1000:	test: 0.7962834	best: 0.7962834 (1000)	total: 11.2s	remaining: 1m 40s
# 1100:	test: 0.7968989	best: 0.7968989 (1100)	total: 12.1s	remaining: 1m 37s
# 1200:	test: 0.7972536	best: 0.7972536 (1200)	total: 12.9s	remaining: 1m 34s
# 1300:	test: 0.7978133	best: 0.7978133 (1300)	total: 13.7s	remaining: 1m 31s
# 1400:	test: 0.7984766	best: 0.7984766 (1400)	total: 14.6s	remaining: 1m 29s
# 1500:	test: 0.7989253	best: 0.7989253 (1500)	total: 15.4s	remaining: 1m 27s
# 1600:	test: 0.7988229	best: 0.7989253 (1500)	total: 16.3s	remaining: 1m 25s
# 1700:	test: 0.7990522	best: 0.7990522 (1700)	total: 17.1s	remaining: 1m 23s
# 1800:	test: 0.7995358	best: 0.7995358 (1800)	total: 18s	remaining: 1m 21s
# 1900:	test: 0.7996412	best: 0.7996412 (1900)	total: 18.8s	remaining: 1m 20s
# 2000:	test: 0.8000467	best: 0.8000467 (2000)	total: 20.1s	remaining: 1m 20s
# 2100:	test: 0.8001412	best: 0.8001412 (2100)	total: 22.8s	remaining: 1m 25s
# 2200:	test: 0.8000983	best: 0.8001412 (2100)	total: 23.8s	remaining: 1m 24s
# 2300:	test: 0.8005494	best: 0.8005494 (2300)	total: 24.7s	remaining: 1m 22s
# 2400:	test: 0.8005315	best: 0.8005494 (2300)	total: 25.5s	remaining: 1m 20s
# 2500:	test: 0.8005218	best: 0.8005494 (2300)	total: 26.4s	remaining: 1m 19s
# 2600:	test: 0.8008664	best: 0.8008664 (2600)	total: 27.2s	remaining: 1m 17s
# 2700:	test: 0.8010676	best: 0.8010676 (2700)	total: 28s	remaining: 1m 15s
# 2800:	test: 0.8012675	best: 0.8012675 (2800)	total: 28.9s	remaining: 1m 14s
# 2900:	test: 0.8011393	best: 0.8012675 (2800)	total: 29.7s	remaining: 1m 12s
# 3000:	test: 0.8012322	best: 0.8012675 (2800)	total: 30.6s	remaining: 1m 11s
# 3100:	test: 0.8014448	best: 0.8014448 (3100)	total: 31.4s	remaining: 1m 9s
# 3200:	test: 0.8016182	best: 0.8016182 (3200)	total: 32.3s	remaining: 1m 8s
# 3300:	test: 0.8016071	best: 0.8016182 (3200)	total: 33.5s	remaining: 1m 7s
# 3400:	test: 0.8020828	best: 0.8020828 (3400)	total: 36.2s	remaining: 1m 10s
# 3500:	test: 0.8021401	best: 0.8021401 (3500)	total: 37.2s	remaining: 1m 9s
# 3600:	test: 0.8024857	best: 0.8024857 (3600)	total: 38s	remaining: 1m 7s
# 3700:	test: 0.8031151	best: 0.8031151 (3700)	total: 38.9s	remaining: 1m 6s
# 3800:	test: 0.8028876	best: 0.8031151 (3700)	total: 39.7s	remaining: 1m 4s
# 3900:	test: 0.8027668	best: 0.8031151 (3700)	total: 40.5s	remaining: 1m 3s
# 4000:	test: 0.8028176	best: 0.8031151 (3700)	total: 41.4s	remaining: 1m 2s
# 4100:	test: 0.8031255	best: 0.8031255 (4100)	total: 42.2s	remaining: 1m
# 4200:	test: 0.8033318	best: 0.8033318 (4200)	total: 43.1s	remaining: 59.5s
# 4300:	test: 0.8029052	best: 0.8033318 (4200)	total: 43.9s	remaining: 58.2s
# 4400:	test: 0.8030823	best: 0.8033318 (4200)	total: 44.8s	remaining: 57s
# 4500:	test: 0.8029703	best: 0.8033318 (4200)	total: 45.6s	remaining: 55.7s
# 4600:	test: 0.8034719	best: 0.8034719 (4600)	total: 46.7s	remaining: 54.9s
# 4700:	test: 0.8030496	best: 0.8034719 (4600)	total: 49.4s	remaining: 55.7s
# 4800:	test: 0.8032078	best: 0.8034719 (4600)	total: 50.6s	remaining: 54.8s
# 4900:	test: 0.8033772	best: 0.8034719 (4600)	total: 51.5s	remaining: 53.5s
# 5000:	test: 0.8032970	best: 0.8034719 (4600)	total: 52.3s	remaining: 52.3s
# 5100:	test: 0.8032753	best: 0.8034719 (4600)	total: 53.2s	remaining: 51.1s
# 5200:	test: 0.8033391	best: 0.8034719 (4600)	total: 54s	remaining: 49.8s
# 5300:	test: 0.8039206	best: 0.8039206 (5300)	total: 54.8s	remaining: 48.6s
# 5400:	test: 0.8033963	best: 0.8039206 (5300)	total: 55.7s	remaining: 47.4s
# 5500:	test: 0.8036988	best: 0.8039206 (5300)	total: 56.5s	remaining: 46.2s
# 5600:	test: 0.8038337	best: 0.8039206 (5300)	total: 57.3s	remaining: 45s
# 5700:	test: 0.8038805	best: 0.8039206 (5300)	total: 58.2s	remaining: 43.9s
# 5800:	test: 0.8038393	best: 0.8039206 (5300)	total: 59s	remaining: 42.7s
# 5900:	test: 0.8035977	best: 0.8039206 (5300)	total: 59.8s	remaining: 41.6s
# 6000:	test: 0.8038913	best: 0.8039206 (5300)	total: 1m 2s	remaining: 41.6s
# 6100:	test: 0.8036815	best: 0.8039206 (5300)	total: 1m 4s	remaining: 40.9s
# 6200:	test: 0.8040914	best: 0.8040914 (6200)	total: 1m 4s	remaining: 39.7s
# 6300:	test: 0.8041460	best: 0.8041460 (6300)	total: 1m 5s	remaining: 38.6s
# 6400:	test: 0.8041167	best: 0.8041460 (6300)	total: 1m 6s	remaining: 37.4s
# 6500:	test: 0.8041234	best: 0.8041460 (6300)	total: 1m 7s	remaining: 36.3s
# 6600:	test: 0.8037237	best: 0.8041460 (6300)	total: 1m 8s	remaining: 35.1s
# 6700:	test: 0.8038261	best: 0.8041460 (6300)	total: 1m 9s	remaining: 34s
# 6800:	test: 0.8039322	best: 0.8041460 (6300)	total: 1m 9s	remaining: 32.9s
# 6900:	test: 0.8044035	best: 0.8044035 (6900)	total: 1m 10s	remaining: 31.8s
# 7000:	test: 0.8044596	best: 0.8044596 (7000)	total: 1m 11s	remaining: 30.7s
# 7100:	test: 0.8046714	best: 0.8046714 (7100)	total: 1m 12s	remaining: 29.6s
# 7200:	test: 0.8047125	best: 0.8047125 (7200)	total: 1m 13s	remaining: 28.5s
# 7300:	test: 0.8044899	best: 0.8047125 (7200)	total: 1m 15s	remaining: 28s
# 7400:	test: 0.8045117	best: 0.8047125 (7200)	total: 1m 17s	remaining: 27.2s
# 7500:	test: 0.8048859	best: 0.8048859 (7500)	total: 1m 18s	remaining: 26.1s
# 7600:	test: 0.8047880	best: 0.8048859 (7500)	total: 1m 19s	remaining: 25s
# 7700:	test: 0.8050081	best: 0.8050081 (7700)	total: 1m 19s	remaining: 23.9s
# 7800:	test: 0.8051153	best: 0.8051153 (7800)	total: 1m 20s	remaining: 22.8s
# 7900:	test: 0.8050447	best: 0.8051153 (7800)	total: 1m 21s	remaining: 21.7s
# 8000:	test: 0.8052184	best: 0.8052184 (8000)	total: 1m 22s	remaining: 20.6s
# 8100:	test: 0.8051788	best: 0.8052184 (8000)	total: 1m 23s	remaining: 19.5s
# 8200:	test: 0.8049749	best: 0.8052184 (8000)	total: 1m 24s	remaining: 18.5s
# 8300:	test: 0.8047970	best: 0.8052184 (8000)	total: 1m 25s	remaining: 17.4s
# 8400:	test: 0.8049601	best: 0.8052184 (8000)	total: 1m 25s	remaining: 16.3s
# 8500:	test: 0.8051186	best: 0.8052184 (8000)	total: 1m 26s	remaining: 15.3s
# 8600:	test: 0.8051068	best: 0.8052184 (8000)	total: 1m 28s	remaining: 14.4s
# 8700:	test: 0.8049554	best: 0.8052184 (8000)	total: 1m 30s	remaining: 13.6s
# 8800:	test: 0.8049521	best: 0.8052184 (8000)	total: 1m 31s	remaining: 12.5s
# 8900:	test: 0.8052579	best: 0.8052579 (8900)	total: 1m 32s	remaining: 11.4s
# 9000:	test: 0.8053486	best: 0.8053486 (9000)	total: 1m 33s	remaining: 10.4s
# 9100:	test: 0.8051726	best: 0.8053486 (9000)	total: 1m 34s	remaining: 9.31s
# 9200:	test: 0.8049453	best: 0.8053486 (9000)	total: 1m 35s	remaining: 8.26s
# 9300:	test: 0.8050182	best: 0.8053486 (9000)	total: 1m 35s	remaining: 7.21s
# 9400:	test: 0.8051512	best: 0.8053486 (9000)	total: 1m 36s	remaining: 6.17s
# 9500:	test: 0.8053789	best: 0.8053789 (9500)	total: 1m 37s	remaining: 5.13s
# 9600:	test: 0.8050924	best: 0.8053789 (9500)	total: 1m 38s	remaining: 4.09s
# 9700:	test: 0.8052484	best: 0.8053789 (9500)	total: 1m 39s	remaining: 3.06s
# 9800:	test: 0.8055473	best: 0.8055473 (9800)	total: 1m 40s	remaining: 2.03s
# 9900:	test: 0.8053734	best: 0.8055473 (9800)	total: 1m 42s	remaining: 1.02s
# 9999:	test: 0.8055699	best: 0.8055699 (9999)	total: 1m 44s	remaining: 0us
# bestTest = 0.8055698911
# bestIteration = 9999

# %%
print(f"NDCG@5: {ndcg_calc(test_df, X_test, catboost_model, 5)}")
print(f"NDCG@10: {ndcg_calc(test_df, X_test, catboost_model, 10)}")
print(f"NDCG@50: {ndcg_calc(test_df, X_test, catboost_model, 50)}")
# Out:
# NDCG@5: 0.5406855930718129
# NDCG@10: 0.5491067934887015
# NDCG@50: 0.6393799916577184

# %% [markdown]
# Метрики не сильно отличаются от метрик, полученных с помощью LightGBM, разница не более 1.5% в пользу CatBoost
